# %% [markdown]
# # SSD300 Training Tutorial
#
# This tutorial explains how to train an SSD300 on the Pascal VOC datasets. The preset parameters reproduce the training of the original SSD300 "07+12" model. Training SSD512 works simiarly, so there's no extra tutorial for that. The same goes for training on other datasets.
#
# You can find a summary of a full training here to get an impression of what it should look like:
# [SSD300 "07+12" training summary](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md)

# %% [markdown]
# ## ONLY IF ON GOOGLE COLLAB
#
# Don't run these cells if you're working locally, with the environment from requirements.txt
#
# First, need to adjust the python environment,

# %%
# !pip uninstall -y tensorflow
# !pip install keras==2.2.4
# !pip install tensorflow==1.15.5
# !pip install tensorflow-gpu==1.15.5

# %% [markdown]
# Then mount Drive and copy the code library from drive to current workspace

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import sys
# print(sys.version_info)
# !pip list

# %%
# from distutils.dir_util import copy_tree
# copy_tree("/content/drive/MyDrive/Colab Notebooks/SSD_library", "./")

# %% [markdown]
# ## Without google collab, start here:

# %%
# %reset -f
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.data_augmentation_chain_variable_input_size import DataAugmentationVariableInputSize
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 0. Preliminary note
#
# All places in the code where you need to make any changes are marked `TODO` and explained accordingly. All code cells that don't contain `TODO` markers just need to be executed.

# %% [markdown]
# ## 1. Set the model configuration parameters
#
# This section sets the configuration parameters for the model definition. The parameters set here are being used both by the `ssd_300()` function that builds the SSD300 model as well as further down by the constructor for the `SSDInputEncoder` object that is needed to run the training. Most of these parameters are needed to define the anchor boxes.
#
# The parameters as set below produce the original SSD300 architecture that was trained on the Pascal VOC datsets, i.e. they are all chosen to correspond exactly to their respective counterparts in the `.prototxt` file that defines the original Caffe implementation. Note that the anchor box scaling factors of the original SSD implementation vary depending on the datasets on which the models were trained. The scaling factors used for the MS COCO datasets are smaller than the scaling factors used for the Pascal VOC datasets. The reason why the list of scaling factors has 7 elements while there are only 6 predictor layers is that the last scaling factor is used for the second aspect-ratio-1 box of the last predictor layer. Refer to the documentation for details.
#
# As mentioned above, the parameters set below are not only needed to build the model, but are also passed to the `SSDInputEncoder` constructor further down, which is responsible for matching and encoding ground truth boxes and anchor boxes during the training. In order to do that, it needs to know the anchor box parameters.

# %%
img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
#todo choose your own number of positive classes:
n_classes =8 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## 2. Build or load the model
#
# You will want to execute either of the two code cells in the subsequent two sub-sections, not both.

# %% [markdown]
# ### 2.1 Create a new model and load trained VGG-16 weights into it (or trained SSD weights)
#
# If you want to create a new SSD300 model, this is the relevant section for you. If you want to load a previously saved SSD300 model, skip ahead to section 2.2.
#
# The code cell below does the following things:
# 1. It calls the function `ssd_300()` to build the model.
# 2. It then loads the weights file that is found at `weights_path` into the model. You could load the trained VGG-16 weights or you could load the weights of a trained model. If you want to reproduce the original SSD training, load the pre-trained VGG-16 weights. In any case, you need to set the path to the weights file you want to load on your local machine. Download links to all the trained weights are provided in the [README](https://github.com/pierluigiferrari/ssd_keras/blob/master/README.md) of this repository.
# 3. Finally, it compiles the model for the training. In order to do so, we're defining an optimizer (Adam) and a loss function (SSDLoss) to be passed to the `compile()` method.
#
# Normally, the optimizer of choice would be Adam (commented out below), but since the original implementation uses plain SGD with momentum, we'll do the same in order to reproduce the original training. Adam is generally the superior optimizer, so if your goal is not to have everything exactly as in the original training, feel free to switch to Adam. You might need to adjust the learning rate scheduler below slightly in case you use Adam.
#
# Note that the learning rate that is being set here doesn't matter, because further below we'll pass a learning rate scheduler to the training function, which will overwrite any learning rate set here, i.e. what matters are the learning rates that are defined by the learning rate scheduler.
#
# `SSDLoss` is a custom Keras loss function that implements the multi-task that consists of a log loss for classification and a smooth L1 loss for localization. `neg_pos_ratio` and `alpha` are set as in the paper.

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load: see readme.md to find the link to download
weights_path = r'ModeInitial.h5'

model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

#todo: choose between sgd and adam
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
model.save('Model.h5')
# Out:
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\Bureau\Polytech\Cours 5A\Michelin_Roue\code\Michelin_SSD\code_original\keras_loss_function\keras_ssd_loss.py:95: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\Bureau\Polytech\Cours 5A\Michelin_Roue\code\Michelin_SSD\code_original\keras_loss_function\keras_ssd_loss.py:133: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From c:\Users\sfarf\Bureau\Polytech\Cours 5A\Michelin_Roue\code\Michelin_SSD\code_original\keras_loss_function\keras_ssd_loss.py:74: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\Users\sfarf\Bureau\Polytech\Cours 5A\Michelin_Roue\code\Michelin_SSD\code_original\keras_loss_function\keras_ssd_loss.py:166: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %% [markdown]
# ### 2.2 Load a previously created model
#
# If you have previously created and saved a model and would now like to load it, execute the next code cell. The only thing you need to do here is to set the path to the saved model HDF5 file that you would like to load.
#
# The SSD model contains custom objects: Neither the loss function nor the anchor box or L2-normalization layer types are contained in the Keras core library, so we need to provide them to the model loader.
#
# This next code cell assumes that you want to load a model that was created in 'training' mode. If you want to load a model that was created in 'inference' or 'inference_fast' mode, you'll have to add the `DecodeDetections` or `DecodeDetectionsFast` layer type to the `custom_objects` dictionary below.

# %%
# # TODO: Set the path to the `.h5` file of the model to be loaded.
# model_path = 'Model.h5'

# # We need to create an SSDLoss object in order to pass that to the model loader.
# ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

# K.clear_session() # Clear previous models from memory.

# model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
#                                                'L2Normalization': L2Normalization,
#                                                'compute_loss': ssd_loss.compute_loss})

# %% [markdown]
# ## 3. Set up the data generators for the training
#
# The code cells below set up the data generators for the training and validation datasets to train the model. The settings below reproduce the original SSD training on Pascal VOC 2007 `trainval` plus 2012 `trainval` and validation on Pascal VOC 2007 `test`.
#
# The only thing you need to change here are the filepaths to the datasets on your local machine. Note that parsing the labels from the XML annotations files can take a while.
#
# Note that the generator provides two options to speed up the training. By default, it loads the individual images for a batch from disk. This has two disadvantages. First, for compressed image formats like JPG, this is a huge computational waste, because every image needs to be decompressed again and again every time it is being loaded. Second, the images on disk are likely not stored in a contiguous block of memory, which may also slow down the loading process. The first option that `DataGenerator` provides to deal with this is to load the entire dataset into memory, which reduces the access time for any image to a negligible amount, but of course this is only an option if you have enough free memory to hold the whole dataset. As a second option, `DataGenerator` provides the possibility to convert the dataset into a single HDF5 file. This HDF5 file stores the images as uncompressed arrays in a contiguous block of memory, which dramatically speeds up the loading time. It's not as good as having the images in memory, but it's a lot better than the default option of loading them from their compressed JPG state every time they are needed. Of course such an HDF5 dataset may require significantly more disk space than the compressed images (around 9 GB total for Pascal VOC 2007 `trainval` plus 2012 `trainval` and another 2.6 GB for 2007 `test`). You can later load these HDF5 datasets directly in the constructor.
#
# The original SSD implementation uses a batch size of 32 for the training. In case you run into GPU memory issues, reduce the batch size accordingly. You need at least 7 GB of free GPU memory to train an SSD300 with 20 object classes with a batch size of 32.
#
# The `DataGenerator` itself is fairly generic. I doesn't contain any data augmentation or bounding box encoding logic. Instead, you pass a list of image transformations and an encoder for the bounding boxes in the `transformations` and `label_encoder` arguments of the data generator's `generate()` method, and the data generator will then apply those given transformations and the encoding to the data. Everything here is preset already, but if you'd like to learn more about the data generator and its data augmentation capabilities, take a look at the detailed tutorial in [this](https://github.com/pierluigiferrari/data_generator_object_detection_2d) repository.
#
# The data augmentation settings defined further down reproduce the data augmentation pipeline of the original SSD training. The training generator receives an object `ssd_data_augmentation`, which is a transformation object that is itself composed of a whole chain of transformations that replicate the data augmentation procedure used to train the original Caffe implementation. The validation generator receives an object `resize`, which simply resizes the input images.
#
# An `SSDInputEncoder` object, `ssd_input_encoder`, is passed to both the training and validation generators. As explained above, it matches the ground truth labels to the model's anchor boxes and encodes the box coordinates into the format that the model needs.
#
# In order to train the model on a dataset other than Pascal VOC, either choose `DataGenerator`'s appropriate parser method that corresponds to your data format, or, if `DataGenerator` does not provide a suitable parser for your data format, you can write an additional parser and add it. Out of the box, `DataGenerator` can handle datasets that use the Pascal VOC format (use `parse_xml()`), the MS COCO format (use `parse_json()`) and a wide range of CSV formats (use `parse_csv()`).

# %%
# TODO: Set the paths to your dataset here.
# Images
import os

working_dir = os.getcwd()
images_dir = working_dir + '\\data'

# Ground truth
annotations_dir = working_dir + '\\data'
image_set_filename_train = images_dir + '\\image_names_train.txt'
image_set_filename_val = images_dir + '\\image_names_val.txt'

# todo: define your classes
classes = ['temoin:0', 'temoin:25', 'temoin:80', 'temoin:75', 'temoin:100', 'temoin:50','temoin:90','temoin:95']

train_dataset_path = images_dir
val_dataset_path = images_dir

# %%
#print le name des fichiers dans le dossier
import os
for i in range(10):
    print(os.listdir(images_dir)[i])
# Out:
# 20190215_090438.jpg
# 20190215_090438.xml
# 20190215_090624.jpg
# 20190215_090624.xml
# 20190215_090900.jpg
# 20190215_090900.xml
# 20190215_090952.jpg
# 20190215_090952.xml
# 20190215_104526.jpg
# 20190215_104526.xml

# %%
#Check contenu des fichiers texte
import os
def load_image_paths(txt_file, images_dir, file_extension='txt'):
    with open(txt_file, 'r') as file:
        # Construct the image paths and standardize separators to forward slash
        return [os.path.join(images_dir, f"{line.strip()}.{file_extension}").replace("\\", "/") for line in file.readlines()]

# %%
load_image_paths(image_set_filename_train, images_dir)
# load_image_paths(image_set_filename_val, images_dir)
# Out:
# ['c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_142104.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145832.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_084816.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164700.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161834.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134359.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133749.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141234.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_134703.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140632.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_142252.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_143154.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145156.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190402_143342.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_141701.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_142624.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_090001.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142426.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_085251.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_152721.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085723.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_165049.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_152332.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154528.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190415_132310.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190308_084302.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_123456.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_152915.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154833.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095353.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154326.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_155054.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190423_160246.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145425.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_134504.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132240.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145124.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190418_101255.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095353.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145126.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190329_143959.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_100014.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133652.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_141712.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140202.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/IMG_20190322_160556.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161357.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190402_085333.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160611.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154613.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160703.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_152915.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132516.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145258.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_134256.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145306.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_152245.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134815.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_131940.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154215.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_133042.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_142509.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154623.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190402_085311.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155731.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_142228.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190415_132348.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190415_132136.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190522_133224.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145230.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154551.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190426_132846.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085433.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_150248.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095721.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190418_101420.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155335.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154338.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161744.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_142326.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103606.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190329_094603.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_085302.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154928.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141255.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154420.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095207.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155120.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154236.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190415_132413.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_154343.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_152907.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_085046.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190520_105451.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_141011.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133459.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154905.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_134631.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_150459.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_105121.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_155002.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154859.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_142230.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140153.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190423_160204.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_133011.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190408_153448.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095822.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085559.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134530.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190322_162527.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_155129.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140042.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190418_101239.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155236.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_153328.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140408.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155153.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141357.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085102.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190425_132904.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142322.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_102114.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164620.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190426_132656.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095452.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164741.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_135908.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190429_143416.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095845.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145026.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095526.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145225.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_084925.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190329_143756.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190523_140107.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190308_084334.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152555.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190402_143404.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_141728.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154136.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190408_094738.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145217.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142149.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_102135.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145412.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164402.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085054.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190415_132209.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_085227.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134455.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095146.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145107.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190521_154411.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_085310.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_102619.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152505.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133808.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_085235.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161453.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_153216.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_093051.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_134946.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154546.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095720.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_153558.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132439.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095754.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_142219.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095431.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154051.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190524_145830.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133646.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155156.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_105024.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152857.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190522_133233.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164710.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_142154.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_142816.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_144245.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_105654.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_152045.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_105456.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160433.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154535.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_151701.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142156.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095617.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_151246.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145401.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190528_154933.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_153247.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160900.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190321_103547.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190318_150732.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190405_134155.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_153150.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_155757.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_085204.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095825.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154616.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_140608.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154531.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161717.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152450.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/IMG_20190322_112607.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_160358.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190215_090952.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_084901.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145149.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160419.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141504.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_160648.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103615.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_152253.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134324.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152815.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095547.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145306.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095435.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095141.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095208.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160630.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095547.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_142958.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155251.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190307_162431.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_132054.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190418_101210.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190524_150918.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141454.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_151917.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_150316.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190418_101154.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155809.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190520_105618.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103125.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161531.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_160423.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_131541_HDR.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154443.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164055.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142419.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_134034.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190325_161847.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_141921.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_134321.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_090215.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161915.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_140646.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_142158.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154227.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152634.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141428.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_133402.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133504.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152755.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_144249.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155346.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155035.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154520.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_141616.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190415_132405.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190215_090900.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190307_162449.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_100010.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161725.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190521_154359.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142331.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_090418.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_135142.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190318_150319.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_152347.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164527.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_162006.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_151759.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_102157.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164016.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190408_094612.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190318_145854.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085149.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190321_131318.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_084605.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161953.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190321_135804.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_145116.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_090305.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_133130.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_170915.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145105.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190325_162359.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103416.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155209.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190321_103831.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140510.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190426_132711.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164634.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164442.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_144720.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190426_133154.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190423_160221.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_150737.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_155747.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_143035.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190322_162538.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_085303.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_134805.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_150412.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154729.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190415_132324.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190426_132535.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_144726.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103102.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_085512.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_084831.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190528_154501.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160348.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_165330.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154133.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155741.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133525.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_134954.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155108.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164253.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_151855.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_085544.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_085214.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190524_150453.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190325_165254.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160658.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154007.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133455.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141517.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154542.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190402_085627.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190405_162439.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095707.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_142005.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145407.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085113.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_131951.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/IMG_20190329_094718.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190522_133145.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155644.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141630.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145143.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152439.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_105011.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_153102.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095530.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145341.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134727.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190405_133907.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154606.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190528_154937.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095603.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141658.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160647.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190405_162452.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160350.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_152320.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190325_162205.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_131905.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_163903.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190321_085819.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161749.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095346.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095314.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_160703.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154724.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_144404.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190325_165159.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_084954.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_105338.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190325_165417.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190423_160118.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_134231.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155100.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095106.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103421.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_133032.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_155850.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132232.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155348.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160638.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160222.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_084518.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_142810.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_102304.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190520_105541.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190322_162626.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154743.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_141530.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190405_134043.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_093038.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_123446.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155340.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134249.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_133058.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160314.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190405_162519.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141241.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190308_084248.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095355.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190408_094512.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_141557.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134749.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190524_145615.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160143.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133736.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190423_160127.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154450.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_123429.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190425_132840.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155008.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190429_144903.txt',
# ...
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154403.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190307_162550.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155241.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_154209.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095509.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190408_094420.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190528_154610.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142245.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_150607.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140052.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_151907.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190412_085447.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160339.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190408_153349.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_123627.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190423_160335.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103335.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_142511.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155604.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133638.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145443.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154647.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152914.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_123451.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132147.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_153138.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155445.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_144830.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190423_160153.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_145955.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_155055.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_142736.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190401_085526.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_133334.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_142949.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_165005.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_151231.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154720.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190410_095156.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_153159.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132055.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_133259.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_165215.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_141714.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190405_162348.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140251.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155509.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_155655.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134556.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_143037.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_092753.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103352.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190215_090624.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190327_084917.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164228.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_140530.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_153045.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161625.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_152827.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190419_095201.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_154747.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_145043.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154117.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190411_095517.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103557.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_164511.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_142254.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_152026.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103034.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190705_141650.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154821.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190524_150030.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103442.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155223.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133727.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_102239.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_134734.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190611_145328.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161441.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190426_132749.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_154141.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_133451.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161705.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_133303.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_155024.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_154608.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_131925.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155708.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_134202.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190515_133017.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145021.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190528_154435.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_160721.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_085801.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134909.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190524_150027.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_145208.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132010.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190520_105607.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190704_154142.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_160314.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103357.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190506_151603.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190603_141901.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190514_105313.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190510_102321.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190326_132021.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190527_133830.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190417_132349.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190425_132852.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_154625.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_153519.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190529_145605.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190523_140016.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_165112.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190329_143951.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_153343.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190321_103625.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190604_155627.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_131600_HDR.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134411.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190409_154938.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190418_101049.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134825.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190503_141541.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_160322.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_160125.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190509_103545.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_155636.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190426_132547.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190325_161806.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190313_131822.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190613_161340.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190606_154349.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190424_155056.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190416_134423.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190403_150013.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190520_105516.txt',
#  'c:/Users/sfarf/Bureau/Polytech/Cours 5A/Michelin_Roue/code/Michelin_SSD/code_original/data/20190404_092649.txt',
#  ...]

# %%
# # reload existing dataset
# train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=train_dataset_path)
# val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=val_dataset_path)

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.


train_dataset.parse_xml(images_dirs=[images_dir],
                            image_set_filenames=[image_set_filename_train],
                            annotations_dirs=[annotations_dir],
                            classes=classes,
                            include_classes='all',
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

val_dataset.parse_xml(images_dirs=[images_dir],
                          image_set_filenames=[image_set_filename_val],
                          annotations_dirs=[annotations_dir],
                          classes=classes,
                          include_classes='all',
                          exclude_truncated=False,
                          exclude_difficult=False,
                          ret=False)

# parse_xml_safe(train_dataset, [images_dir], [image_set_filename_train], [annotations_dir], classes, 'all', False, False, False)
# parse_xml_safe(val_dataset, [images_dir], [image_set_filename_val], [annotations_dir], classes, 'all', False, False, False)


# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path=train_dataset_path,
#                                       resize=False,
#                                       variable_image_size=True,
#                                       verbose=True)

# val_dataset.create_hdf5_dataset(file_path=val_dataset_path,
#                                     resize=False,
#                                     variable_image_size=True,
#                                     verbose=True)
# Out:
# Processing image set 'image_names_train.txt': 100%|██████████| 1082/1082 [00:11<00:00, 91.07it/s]
# Processing image set 'image_names_val.txt': 100%|██████████| 271/271 [00:02<00:00, 93.83it/s]

# %%
#train = 20190613_154507
# val = 20190321_135741
#Sizes of the datasets
print(f"training dataset:\t{train_dataset.get_dataset_size()}")
print(f"validation dataset:\t{val_dataset.get_dataset_size()}")

#Print the image dimensions
print(f"Image shape: {train_dataset}")
# Out:
# training dataset:	1082
# validation dataset:	271
# Image shape: <data_generator.object_detection_2d_data_generator.DataGenerator object at 0x0000015E1ED57E88>

# %%
# 3: Set the batch size.

from data_generator.data_augmentation_chain_constant_input_size import DataAugmentationConstantInputSize
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
# if you want to add dataaugmentation, choose one:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

'''
ssd_data_augmentation = DataAugmentationVariableInputSize(resize_height=img_height, 
                                                          resize_width=img_width, 
                                                          background=mean_color)
'''
# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  1082
# Number of images in the validation dataset:	   271

# %%
train_generator
# Out:
# <generator object DataGenerator.generate at 0x0000015E203A29C8>

# %% [markdown]
# ## 4. Set the remaining training parameters
#
# We've already chosen an optimizer and set the batch size above, now let's set the remaining training parameters. I'll set one epoch to consist of 1,000 training steps. The next code cell defines a learning rate schedule that replicates the learning rate schedule of the original Caffe implementation for the training of the SSD300 Pascal VOC "07+12" model. That model was trained for 120,000 steps with a learning rate of 0.001 for the first 80,000 steps, 0.0001 for the next 20,000 steps, and 0.00001 for the last 20,000 steps. If you're training on a different dataset, define the learning rate schedule however you see fit.
#
# I'll set only a few essential Keras callbacks below, feel free to add more callbacks if you want TensorBoard summaries or whatever. We obviously need the learning rate scheduler and we want to save the best models during the training. It also makes sense to continuously stream our training history to a CSV log file after every epoch, because if we didn't do that, in case the training terminates with an exception at some point or if the kernel of this Jupyter notebook dies for some reason or anything like that happens, we would lose the entire history for the trained epochs. Finally, we'll also add a callback that makes sure that the training terminates if the loss becomes `NaN`. Depending on the optimizer you use, it can happen that the loss becomes `NaN` during the first iterations of the training. In later iterations it's less of a risk. For example, I've never seen a `NaN` loss when I trained SSD using an Adam optimizer, but I've seen a `NaN` loss a couple of times during the very first couple of hundred training steps of training a new model when I used an SGD optimizer.

# %%
# Define a learning rate schedule.

def lr_schedule(epoch):
    if epoch < 80:
        return 0.001
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=r'saved_models/12_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
#model_checkpoint.best = 

csv_logger = CSVLogger(filename=r'saved_models/12_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %% [markdown]
# ## 5. Train

# %% [markdown]
# In order to reproduce the training of the "07+12" model mentioned above, at 1,000 training steps per epoch you'd have to train for 120 epochs. That is going to take really long though, so you might not want to do all 120 epochs in one go and instead train only for a few epochs at a time. You can find a summary of a full training [here](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md).
#
# In order to only run a partial training and resume smoothly later on, there are a few things you should note:
# 1. Always load the full model if you can, rather than building a new model and loading previously saved weights into it. Optimizers like SGD or Adam keep running averages of past gradient moments internally. If you always save and load full models when resuming a training, then the state of the optimizer is maintained and the training picks up exactly where it left off. If you build a new model and load weights into it, the optimizer is being initialized from scratch, which, especially in the case of Adam, leads to small but unnecessary setbacks every time you resume the training with previously saved weights.
# 2. In order for the learning rate scheduler callback above to work properly, `fit_generator()` needs to know which epoch we're in, otherwise it will start with epoch 0 every time you resume the training. Set `initial_epoch` to be the next epoch of your training. Note that this parameter is zero-based, i.e. the first epoch is epoch 0. If you had trained for 10 epochs previously and now you'd want to resume the training from there, you'd set `initial_epoch = 10` (since epoch 10 is the eleventh epoch). Furthermore, set `final_epoch` to the last epoch you want to run. To stick with the previous example, if you had trained for 10 epochs previously and now you'd want to train for another 10 epochs, you'd set `initial_epoch = 10` and `final_epoch = 20`.
# 3. In order for the model checkpoint callback above to work correctly after a kernel restart, set `model_checkpoint.best` to the best validation loss from the previous training. If you don't do this and a new `ModelCheckpoint` object is created after a kernel restart, that object obviously won't know what the last best validation loss was, so it will always save the weights of the first epoch of your new training and record that loss as its new best loss. This isn't super-important, I just wanted to mention it.

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch= 0
# choose a few epochs first, as you can retrain from a previous step, as explained
final_epoch= 50
# todo adjust step_per_epoch
steps_per_epoch = ceil(train_dataset_size/batch_size)
# steps_per_epoch = ceil(train_dataset_size/batch_size) 

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From c:\Users\sfarf\miniconda3\envs\env_tp_michelin\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 905s 27s/step - loss: 1827527336.3874 - val_loss: 59.7794
#
# Epoch 00001: val_loss improved from inf to 59.77938, saving model to saved_models/12_epoch-01_loss-1837370391.4588_val_loss-59.7794.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 882s 26s/step - loss: 2248.2159 - val_loss: 58.1780
#
# Epoch 00002: val_loss improved from 59.77938 to 58.17799, saving model to saved_models/12_epoch-02_loss-2259.7273_val_loss-58.1780.h5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 574.6848 - val_loss: 66.5718
#
# Epoch 00003: val_loss did not improve from 58.17799
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 874s 26s/step - loss: 399.4654 - val_loss: 58.8753
#
# Epoch 00004: val_loss did not improve from 58.17799
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 872s 26s/step - loss: 456.9858 - val_loss: 16.1562
#
# Epoch 00005: val_loss improved from 58.17799 to 16.15624, saving model to saved_models/12_epoch-05_loss-459.3425_val_loss-16.1562.h5
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 79.3388 - val_loss: 14.0914
#
# Epoch 00006: val_loss improved from 16.15624 to 14.09139, saving model to saved_models/12_epoch-06_loss-79.6853_val_loss-14.0914.h5
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 120.1381 - val_loss: 13.7863
#
# Epoch 00007: val_loss improved from 14.09139 to 13.78625, saving model to saved_models/12_epoch-07_loss-120.7080_val_loss-13.7863.h5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 878s 26s/step - loss: 16.9413 - val_loss: 13.8375
#
# Epoch 00008: val_loss did not improve from 13.78625
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 874s 26s/step - loss: 75048.7292 - val_loss: 14.0107
#
# Epoch 00009: val_loss did not improve from 13.78625
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 18.0897 - val_loss: 16.7197
#
# Epoch 00010: val_loss did not improve from 13.78625
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 872s 26s/step - loss: 2399493.6411 - val_loss: 13.9562
#
# Epoch 00011: val_loss did not improve from 13.78625
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 875s 26s/step - loss: 16.9111 - val_loss: 13.8850
#
# Epoch 00012: val_loss did not improve from 13.78625
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 875s 26s/step - loss: 18.1130 - val_loss: 14.4819
#
# Epoch 00013: val_loss did not improve from 13.78625
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 871s 26s/step - loss: 17.7967 - val_loss: 13.3998
#
# Epoch 00014: val_loss improved from 13.78625 to 13.39983, saving model to saved_models/12_epoch-14_loss-17.7979_val_loss-13.3998.h5
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 872s 26s/step - loss: 18.1851 - val_loss: 14.3047
#
# Epoch 00015: val_loss did not improve from 13.39983
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 875s 26s/step - loss: 24.9012 - val_loss: 13.5255
#
# Epoch 00016: val_loss did not improve from 13.39983
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 874s 26s/step - loss: 17.9713 - val_loss: 13.4698
#
# Epoch 00017: val_loss did not improve from 13.39983
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 881s 26s/step - loss: 17.5393 - val_loss: 13.2176
#
# Epoch 00018: val_loss improved from 13.39983 to 13.21757, saving model to saved_models/12_epoch-18_loss-17.5355_val_loss-13.2176.h5
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 886s 26s/step - loss: 20.7053 - val_loss: 13.1479
#
# Epoch 00019: val_loss improved from 13.21757 to 13.14787, saving model to saved_models/12_epoch-19_loss-20.6972_val_loss-13.1479.h5
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 876s 26s/step - loss: 18.4236 - val_loss: 13.4307
#
# Epoch 00020: val_loss did not improve from 13.14787
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 875s 26s/step - loss: 15.4039 - val_loss: 13.1095
#
# Epoch 00021: val_loss improved from 13.14787 to 13.10950, saving model to saved_models/12_epoch-21_loss-15.4083_val_loss-13.1095.h5
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 875s 26s/step - loss: 15.0131 - val_loss: 12.7710
#
# Epoch 00022: val_loss improved from 13.10950 to 12.77099, saving model to saved_models/12_epoch-22_loss-15.0152_val_loss-12.7710.h5
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 876s 26s/step - loss: 14.5286 - val_loss: 12.6956
#
# Epoch 00023: val_loss improved from 12.77099 to 12.69560, saving model to saved_models/12_epoch-23_loss-14.5365_val_loss-12.6956.h5
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 876s 26s/step - loss: 14.0727 - val_loss: 12.5923
#
# Epoch 00024: val_loss improved from 12.69560 to 12.59230, saving model to saved_models/12_epoch-24_loss-14.0797_val_loss-12.5923.h5
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 880s 26s/step - loss: 13.0209 - val_loss: 12.4887
#
# Epoch 00025: val_loss improved from 12.59230 to 12.48872, saving model to saved_models/12_epoch-25_loss-13.0250_val_loss-12.4887.h5
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 874s 26s/step - loss: 13.0475 - val_loss: 12.4027
#
# Epoch 00026: val_loss improved from 12.48872 to 12.40269, saving model to saved_models/12_epoch-26_loss-13.0461_val_loss-12.4027.h5
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 875s 26s/step - loss: 526507079.0624 - val_loss: 110.0494
#
# Epoch 00027: val_loss did not improve from 12.40269
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 871s 26s/step - loss: 200.1621 - val_loss: 14.5850
#
# Epoch 00028: val_loss did not improve from 12.40269
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 31.1492 - val_loss: 13.0638
#
# Epoch 00029: val_loss did not improve from 12.40269
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 13.6746 - val_loss: 12.8225
#
# Epoch 00030: val_loss did not improve from 12.40269
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 872s 26s/step - loss: 13.1947 - val_loss: 12.6709
#
# Epoch 00031: val_loss did not improve from 12.40269
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 3589501901793.4946 - val_loss: 36.6463
#
# Epoch 00032: val_loss did not improve from 12.40269
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 873s 26s/step - loss: 20.3186 - val_loss: 13.7046
#
# Epoch 00033: val_loss did not improve from 12.40269
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 868s 26s/step - loss: 17.1686 - val_loss: 12.9733
#
# Epoch 00034: val_loss did not improve from 12.40269
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 863s 25s/step - loss: 17.2501 - val_loss: 12.4459
#
# Epoch 00035: val_loss did not improve from 12.40269
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 866s 25s/step - loss: 16.6679 - val_loss: 12.2984
#
# Epoch 00036: val_loss improved from 12.40269 to 12.29843, saving model to saved_models/12_epoch-36_loss-16.6773_val_loss-12.2984.h5
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 876s 26s/step - loss: 16.6573 - val_loss: 12.2016
#
# Epoch 00037: val_loss improved from 12.29843 to 12.20161, saving model to saved_models/12_epoch-37_loss-16.6704_val_loss-12.2016.h5
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 869s 26s/step - loss: 16.2257 - val_loss: 12.1346
#
# Epoch 00038: val_loss improved from 12.20161 to 12.13464, saving model to saved_models/12_epoch-38_loss-16.2300_val_loss-12.1346.h5
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 864s 25s/step - loss: 16.1161 - val_loss: 12.0898
#
# Epoch 00039: val_loss improved from 12.13464 to 12.08983, saving model to saved_models/12_epoch-39_loss-16.1131_val_loss-12.0898.h5
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 865s 25s/step - loss: 16.6074 - val_loss: 12.1380
#
# Epoch 00040: val_loss did not improve from 12.08983
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 866s 25s/step - loss: 16.0711 - val_loss: 11.9833
#
# Epoch 00041: val_loss improved from 12.08983 to 11.98327, saving model to saved_models/12_epoch-41_loss-16.0750_val_loss-11.9833.h5
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 951s 28s/step - loss: 16.0917 - val_loss: 12.0506
#
# Epoch 00042: val_loss did not improve from 11.98327
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 917s 27s/step - loss: 16.2898 - val_loss: 11.9881
#
# Epoch 00043: val_loss did not improve from 11.98327
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 900s 26s/step - loss: 16.5172 - val_loss: 11.9860
#
# Epoch 00044: val_loss did not improve from 11.98327
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 940s 28s/step - loss: 16.7116 - val_loss: 11.9587
#
# Epoch 00045: val_loss improved from 11.98327 to 11.95869, saving model to saved_models/12_epoch-45_loss-16.7131_val_loss-11.9587.h5
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 905s 27s/step - loss: 16.1491 - val_loss: 12.0230
#
# Epoch 00046: val_loss did not improve from 11.95869
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 901s 26s/step - loss: 16.3327 - val_loss: 11.9276
#
# Epoch 00047: val_loss improved from 11.95869 to 11.92757, saving model to saved_models/12_epoch-47_loss-16.3404_val_loss-11.9276.h5
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 925s 27s/step - loss: 16.7627 - val_loss: 11.9253
#
# Epoch 00048: val_loss improved from 11.92757 to 11.92526, saving model to saved_models/12_epoch-48_loss-16.7619_val_loss-11.9253.h5
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 936s 28s/step - loss: 15.7321 - val_loss: 11.8639
#
# Epoch 00049: val_loss improved from 11.92526 to 11.86393, saving model to saved_models/12_epoch-49_loss-15.7187_val_loss-11.8639.h5
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 34/34 [==============================] - 920s 27s/step - loss: 16.5279 - val_loss: 11.8900
#
# Epoch 00050: val_loss did not improve from 11.86393

# %% [markdown]
# ## 6. Make predictions
#
# Now let's make some predictions on the validation dataset with the trained model. For convenience we'll use the validation generator that we've already set up above. Feel free to change the batch size.
#
# You can set the `shuffle` option to `False` if you would like to check the model's progress on the same image(s) over the course of the training.

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=32,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)#TEST

# %%
# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # Which batch item to look at
#####################################
# #print("Image:", batch_filenames[i])
# print()
# print("Ground truth boxes:\n")
# print(np.array(batch_original_labels[i]))
#######################################
print("Image:", batch_filenames[i])
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))
# Out:
# Image: c:\Users\sfarf\Bureau\Polytech\Cours 5A\Michelin_Roue\code\Michelin_SSD\code_original\data\20190418_101217.jpg
# Ground truth boxes:
#
# [[  4 178 265 320 487]]

# %%
# 3: Make predictions.

y_pred = model.predict(batch_images)

# %%
y_pred
# Out:
# array([[[1.0000000e+00, 2.0367406e-20, 1.0110408e-12, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [1.0000000e+00, 6.2130780e-11, 1.4457582e-10, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [9.9999988e-01, 6.7422934e-10, 7.9020666e-13, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         ...,
#         [7.7608728e-01, 1.1903415e-02, 2.0841002e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7802026e-01, 1.1903055e-02, 1.6266918e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7674180e-01, 6.4487504e-03, 2.6885930e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01]],
#
#        [[1.0000000e+00, 2.0269048e-20, 1.0073488e-12, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [1.0000000e+00, 6.1888085e-11, 1.4427831e-10, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [9.9999988e-01, 6.7185957e-10, 7.8797163e-13, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         ...,
#         [7.7608728e-01, 1.1903415e-02, 2.0841002e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7802026e-01, 1.1903055e-02, 1.6266918e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7674180e-01, 6.4487504e-03, 2.6885930e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01]],
#
#        [[1.0000000e+00, 2.0660227e-20, 1.0152844e-12, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [1.0000000e+00, 6.2628472e-11, 1.4530538e-10, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [9.9999988e-01, 6.7868450e-10, 7.9563152e-13, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         ...,
#         [7.7608728e-01, 1.1903415e-02, 2.0841002e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7802026e-01, 1.1903055e-02, 1.6266918e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7674180e-01, 6.4487504e-03, 2.6885930e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01]],
#
#        ...,
#
#        [[1.0000000e+00, 2.1835287e-20, 1.0543804e-12, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [1.0000000e+00, 6.3719037e-11, 1.5003257e-10, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [9.9999988e-01, 6.7767941e-10, 8.0659475e-13, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         ...,
#         [7.7608728e-01, 1.1903415e-02, 2.0841002e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7802026e-01, 1.1903055e-02, 1.6266918e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7674180e-01, 6.4487504e-03, 2.6885930e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01]],
#
#        [[1.0000000e+00, 2.0882643e-20, 1.0238350e-12, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [1.0000000e+00, 6.3008411e-11, 1.4610799e-10, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [9.9999988e-01, 6.8099909e-10, 7.9919963e-13, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         ...,
#         [7.7608728e-01, 1.1903420e-02, 2.0841006e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7802026e-01, 1.1903055e-02, 1.6266910e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7674180e-01, 6.4487504e-03, 2.6885930e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01]],
#
#        [[1.0000000e+00, 2.1556217e-20, 1.0452975e-12, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [1.0000000e+00, 6.3358499e-11, 1.4824703e-10, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [9.9999988e-01, 6.8150979e-10, 8.0348846e-13, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         ...,
#         [7.7608728e-01, 1.1903420e-02, 2.0841006e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7802026e-01, 1.1903055e-02, 1.6266910e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01],
#         [7.7674180e-01, 6.4487504e-03, 2.6885925e-02, ...,
#          1.0000000e-01, 2.0000000e-01, 2.0000000e-01]]], dtype=float32)

# %% [markdown]
# Now let's decode the raw predictions in `y_pred`.
#
# Had we created the model in 'inference' or 'inference_fast' mode, then the model's final layer would be a `DecodeDetections` layer and `y_pred` would already contain the decoded predictions, but since we created the model in 'training' mode, the model outputs raw predictions that still need to be decoded and filtered. This is what the `decode_detections()` function is for. It does exactly what the `DecodeDetections` layer would do, but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).
#
# `decode_detections()` with default argument values follows the procedure of the original SSD implementation: First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes, then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45, and out of what is left after that, the top 200 highest confidence boxes are returned. Those settings are for precision-recall scoring purposes though. In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5, since we're only interested in the very confident predictions.

# %%
# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.17,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# %%
y_pred_decoded
# Out:
# [array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]]),
#  array([[  4.  ,   0.17,   8.25, -24.65,  39.74,  42.47],
#         [  4.  ,   0.17,  24.25, -24.65,  55.74,  42.47],
#         [  4.  ,   0.17,  40.25, -24.65,  71.74,  42.47],
#         [  4.  ,   0.17,  56.25, -24.65,  87.74,  42.47],
#         [  4.  ,   0.17,  72.25, -24.65, 103.74,  42.47],
#         [  4.  ,   0.17,  88.25, -24.65, 119.74,  42.47],
#         [  4.  ,   0.17, 104.25, -24.65, 135.74,  42.47],
#         [  4.  ,   0.17, 120.25, -24.65, 151.74,  42.47],
#         [  4.  ,   0.17, 136.25, -24.65, 167.74,  42.47],
#         [  4.  ,   0.17, 152.25, -24.65, 183.74,  42.47],
#         [  4.  ,   0.17, 168.25, -24.65, 199.74,  42.47],
#         [  4.  ,   0.17, 184.25, -24.65, 215.74,  42.47],
#         [  4.  ,   0.17, 200.25, -24.65, 231.74,  42.47],
#         [  4.  ,   0.17, 216.25, -24.65, 247.74,  42.47],
#         [  4.  ,   0.17, 232.25, -24.65, 263.74,  42.47],
#         [  4.  ,   0.17, 248.25, -24.65, 279.74,  42.47],
#         [  4.  ,   0.17, 264.25, -24.65, 295.74,  42.47],
#         [  4.  ,   0.17, 280.63, -25.07, 311.18,  43.46]])]

# %% [markdown]
# We made the predictions on the resized images, but we'd like to visualize the outcome on the original input images, so we'll convert the coordinates accordingly. Don't worry about that opaque `apply_inverse_transforms()` function below, in this simple case it just aplies `(* original_image_size / resized_image_size)` to the box coordinates.

# %%
# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])
# Out:
# Predicted boxes:
#
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.17  16.   -63.    76.   109.  ]
#  [  4.     0.17  47.   -63.   107.   109.  ]
#  [  4.     0.17  77.   -63.   138.   109.  ]
#  [  4.     0.17 108.   -63.   168.   109.  ]
#  [  4.     0.17 139.   -63.   199.   109.  ]
#  [  4.     0.17 169.   -63.   230.   109.  ]
#  [  4.     0.17 200.   -63.   261.   109.  ]
#  [  4.     0.17 231.   -63.   291.   109.  ]
#  [  4.     0.17 262.   -63.   322.   109.  ]
#  [  4.     0.17 292.   -63.   353.   109.  ]
#  [  4.     0.17 323.   -63.   383.   109.  ]
#  [  4.     0.17 354.   -63.   414.   109.  ]
#  [  4.     0.17 384.   -63.   445.   109.  ]
#  [  4.     0.17 415.   -63.   476.   109.  ]
#  [  4.     0.17 446.   -63.   506.   109.  ]
#  [  4.     0.17 477.   -63.   537.   109.  ]
#  [  4.     0.17 507.   -63.   568.   109.  ]
#  [  4.     0.17 539.   -64.   597.   111.  ]]

# %% [markdown]
# Finally, let's draw the predicted boxes onto the image. Each predicted box says its confidence next to the category name. The ground truth boxes are also drawn onto the image in green for comparison.

# %%
# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
classes = ['temoin:0', 'temoin:25', 'temoin:80', 'temoin:75', 'temoin:100', 'temoin:50','temoin:90','temoin:95']

plt.figure(figsize=(20,12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='black', bbox={'facecolor':color, 'alpha':1.0})
